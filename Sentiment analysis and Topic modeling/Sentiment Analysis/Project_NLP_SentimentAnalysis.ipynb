# %% [markdown]
# # Sentiment Analysis
#
# ### https://medium.com/@decimo.me/ควันว่างกับ-sentiment-analysis-a79b46ef9e77

# %%
# ใช้ตัดคำภาษาไทย
import deepcut
# ใช้งาน regex
import re
# จัดการเกี่ยวกับ array
import numpy as np
import pandas as pd
# สำหรับทำ classify และทดสอบโมเดล
from nltk import FreqDist, precision, recall, f_measure, NaiveBayesClassifier
from nltk.classify import apply_features
from nltk.classify import util
# สำหรับสร้างชุดข้อมูลสำหรับ train และ test เพื่อทดสอบประสิทธิภาพ
from sklearn.model_selection import KFold
import collections, itertools

# %%
data_pos = [(line.strip(), 'pos') for line in open("pos.txt", 'r')]
data_neg = [(line.strip(), 'neg') for line in open("neg.txt", 'r')]

# %%
def split_words (sentence):
    return deepcut.tokenize(''.join(sentence.lower().split()))
sentences = [(split_words(sentence), sentiment) for (sentence, sentiment) in data_pos + data_neg]

# %%
sentences
# Out:
# [(['ดี'], 'pos'),
#  ([''], 'pos'),
#  (['ขอบคุณ'], 'pos'),
#  ([''], 'pos'),
#  (['สู้', 'เสมอ'], 'pos'),
#  ([''], 'pos'),
#  (['ผ่าน'], 'pos'),
#  ([''], 'pos'),
#  (['โคตรสนุก'], 'pos'),
#  ([''], 'pos'),
#  (['สุดยอด'], 'pos'),
#  ([''], 'pos'),
#  (['น่ารัก'], 'pos'),
#  ([''], 'pos'),
#  (['ขอบคุณ', 'ทุก'], 'pos'),
#  ([''], 'pos'),
#  (['คง', 'คิด', 'ถึง'], 'pos'),
#  ([''], 'pos'),
#  (['เก็บ', 'เวลา', 'ที่', 'ดี', 'ให้', 'เรา', 'ได้', 'จดจำ'], 'pos'),
#  ([''], 'pos'),
#  (['ทำ', 'ข้อ', 'สอบ', 'ให้', 'ได้'], 'pos'),
#  ([''], 'pos'),
#  (['สู้'], 'pos'),
#  ([''], 'pos'),
#  (['รอย', 'ยิ้ม', 'ใน', 'ความทรงจำ'], 'pos'),
#  ([''], 'pos'),
#  (['ทุก', 'นี้', 'ฉัน', 'คิด', 'ถึง'], 'pos'),
#  ([''], 'pos'),
#  (['ความทรงจำ', 'ที่', 'ดี', 'เหลือเกิน'], 'pos'),
#  ([''], 'pos'),
#  (['รัก', 'มาก', 'คิด', 'ถึง', 'มาก'], 'pos'),
#  ([''], 'pos'),
#  (['ดีใจ'], 'pos'),
#  ([''], 'pos'),
#  (['รัก'], 'pos'),
#  ([''], 'pos'),
#  (['ห่วง'], 'pos'),
#  ([''], 'pos'),
#  (['รัก', 'แฟน', 'ขี้', 'บ่น', 'จัง'], 'pos'),
#  ([''], 'pos'),
#  (['ขอบคุณ', 'ผู้ใจ', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['มิตรภาพ', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['ที่รัก'], 'pos'),
#  ([''], 'pos'),
#  (['ชอบ', 'จัง'], 'pos'),
#  ([''], 'pos'),
#  (['ความทรงจำ', 'ที่', 'ยัง', 'สวยงาม'], 'pos'),
#  ([''], 'pos'),
#  (['ช่วง',
#    'เวลา',
#    'ที่',
#    'รู้จัก',
#    'ถึง',
#    'จะ',
#    'ไม่',
#    'นาน',
#    'แต่',
#    'คือ',
#    'ช่วง',
#    'ที่',
#    'ดี',
#    'ที่สุด'],
#   'pos'),
#  ([''], 'pos'),
#  (['เปลี่ยน', 'ไป', 'รัก', 'รัก', 'จน', 'หมด', 'หัวใจ'], 'pos'),
#  ([''], 'pos'),
#  (['ดีใจ', 'ด้วย'], 'pos'),
#  ([''], 'pos'),
#  (['ปลอด', 'ภัย'], 'pos'),
#  ([''], 'pos'),
#  (['ทรง', 'พระเจริญ'], 'pos'),
#  ([''], 'pos'),
#  (['ใจเย็น'], 'pos'),
#  ([''], 'pos'),
#  (['ดูแล', 'ตัว', 'เอง', 'ด้วย'], 'pos'),
#  ([''], 'pos'),
#  (['ขอบคุณมิตรภาพ', 'ดี', 'เพื่อน', 'ที่', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['โอกาศ', 'ดี', 'แบบ', 'นี้', 'ห้าม', 'พลาด'], 'pos'),
#  ([''], 'pos'),
#  (['ขอบคุณ'], 'pos'),
#  ([''], 'pos'),
#  (['ง่าย'], 'pos'),
#  ([''], 'pos'),
#  (['มอง', 'โลก', 'ใน', 'แง่', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['ไม่', 'ต้อง', 'กลัว'], 'pos'),
#  ([''], 'pos'),
#  (['คุณโชค', 'ดี', 'กว่า', 'หลาย', 'มาก'], 'pos'),
#  ([''], 'pos'),
#  (['อดทน', 'ต่อ', 'ไป'], 'pos'),
#  ([''], 'pos'),
#  (['ชอบ', 'ใคร', 'ก็', 'ชวน', 'มา', 'ลอง', 'ชิม', 'ที่', 'คุณ', 'ทำ'], 'pos'),
#  ([''], 'pos'),
#  (['ดูแล',
#    'ตัว',
#    'เอง',
#    'ก็',
#    'มั่นใจ',
#    'ใน',
#    'ตัว',
#    'เอง',
#    'มาก',
#    'ขึ้น',
#    'ยิ้ม',
#    'บ่อย'],
#   'pos'),
#  ([''], 'pos'),
#  (['คบนาน', 'สนิท', 'มาก', 'เดี๋ยว', 'ก็', 'หาย'], 'pos'),
#  ([''], 'pos'),
#  (['ใช้', 'ความ', 'รัก', 'พลัง'], 'pos'),
#  ([''], 'pos'),
#  (['ไม่',
#    'ขี้ง',
#    'อน',
#    'ไม่',
#    'น้อยใจ',
#    'ใคร',
#    'แม้',
#    'แต่',
#    'เพื่อน',
#    'สนิท'],
#   'pos'),
#  ([''], 'pos'),
#  (['รัก', 'ตัว', 'เอง', 'ให้', 'มาก'], 'pos'),
#  ([''], 'pos'),
#  (['ไม่', 'ต้อง', 'คิด', 'มาก'], 'pos'),
#  ([''], 'pos'),
#  (['กำลังใจ', 'ให้'], 'pos'),
#  ([''], 'pos'),
#  (['พรุ่ง', 'นี้', 'ต้อง', 'ดี', 'กว่า', 'นี้'], 'pos'),
#  ([''], 'pos'),
#  (['ความ', 'มิตร', 'จริงใจ', 'ทำ', 'ดี', 'ต่อ'], 'pos'),
#  ([''], 'pos'),
#  (['ขอบใจ', 'มาก'], 'pos'),
#  ([''], 'pos'),
#  (['โคตร', 'หล่อ'], 'pos'),
#  ([''], 'pos'),
#  (['หยุด', 'ยิ้ม', 'ไม่', 'ได้'], 'pos'),
#  ([''], 'pos'),
#  (['อารมณ์', 'ดี', 'เพราะ', 'ความ', 'สุข'], 'pos'),
#  ([''], 'pos'),
#  (['ทั้ง', 'คู่', 'เหมาะสม', 'มาก'], 'pos'),
#  ([''], 'pos'),
#  (['สวยงาม', 'มาก'], 'pos'),
#  ([''], 'pos'),
#  (['สิ่ง', 'ที่', 'รู้สึก', 'อยาก', 'เห็น', 'มาก'], 'pos'),
#  ([''], 'pos'),
#  (['เค้า', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['บรรยากาศ', 'อบอุ่น', 'ดี', 'มาก'], 'pos'),
#  ([''], 'pos'),
#  (['ชอบ', 'จัง'], 'pos'),
#  ([''], 'pos'),
#  (['ขำตลก', 'จริง'], 'pos'),
#  ([''], 'pos'),
#  (['ดี'], 'pos'),
#  ([''], 'pos'),
#  (['ทำไม', 'น่า', 'รัก', 'ขนาด', 'นี้'], 'pos'),
#  ([''], 'pos'),
#  (['น่า', 'รัก', 'มา', 'ก', 'อบอุ่น'], 'pos'),
#  ([''], 'pos'),
#  (['เดินทาง', 'ปลอด', 'ภัย'], 'pos'),
#  ([''], 'pos'),
#  (['อบอุ่นจัง'], 'pos'),
#  ([''], 'pos'),
#  (['โครตฮา', 'หัวเราะ', 'อร่อย', 'มาก'], 'pos'),
#  ([''], 'pos'),
#  (['ชอบ'], 'pos'),
#  ([''], 'pos'),
#  (['ไม่', 'เดือดร้อน'], 'pos'),
#  ([''], 'pos'),
#  (['ทำไม', 'น่า', 'ร๊าก'], 'pos'),
#  ([''], 'pos'),
#  (['นี่', 'ถือ', 'ตัวอย่าง', 'ที่', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['อวยพร'], 'pos'),
#  ([''], 'pos'),
#  (['โชค', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['อย่า', 'ได้', 'ไป', 'หวัง', 'อะไร', 'ลม', 'แล้ง'], 'pos'),
#  ([''], 'pos'),
#  (['ความ', 'หวัง', 'ใน', 'อนาคต'], 'pos'),
#  ([''], 'pos'),
#  (['เขียน', 'ได้', 'ดี', 'อ่าน', 'เพลิน', 'มาก'], 'pos'),
#  ([''], 'pos'),
#  (['อย่า', 'ปล่อย', 'ให้', 'อดีต', 'ทำร้าย', 'ปัจจุบัน'], 'pos'),
#  ([''], 'pos'),
#  (['เธอ', 'คง', 'ความ', 'สุข', 'ดี', 'ใน', 'ที่', 'ฉัน', 'ความ', 'สุข', 'เธอ'],
#   'pos'),
#  ([''], 'pos'),
#  (['ขอ', 'ให้', 'ความ', 'สุข'], 'pos'),
#  ([''], 'pos'),
#  (['ความ', 'รู้สึก', 'ที่', 'ยัง', 'เหมือน', 'เดิม'], 'pos'),
#  ([''], 'pos'),
#  (['ให้', 'โอกาส'], 'pos'),
#  ([''], 'pos'),
#  (['ความ', 'สุข'], 'pos'),
#  ([''], 'pos'),
#  (['ประโยชน์'], 'pos'),
#  ([''], 'pos'),
#  (['รัก'], 'pos'),
#  ([''], 'pos'),
#  (['ดี', 'ที่สุด'], 'pos'),
#  ([''], 'pos'),
#  (['ดีใจ', 'ความ', 'สุข'], 'pos'),
#  ([''], 'pos'),
#  (['ยัง', 'ไม่', 'ลืม'], 'pos'),
#  ([''], 'pos'),
#  (['ชอบ', 'ที่', 'เธอ', 'แกล้ง', 'เรา', 'แอบ', 'ไป', 'ยิ้ม'], 'pos'),
#  ([''], 'pos'),
#  (['กิน', 'ของ', 'อร่อย', 'ความ', 'สุข'], 'pos'),
#  ([''], 'pos'),
#  (['สาธุ'], 'pos'),
#  ([''], 'pos'),
#  (['เอา', 'เงิน', 'มา', 'บริจาค'], 'pos'),
#  ([''], 'pos'),
#  (['ความ',
#    'พยายาม',
#    'อยู่',
#    'ที่',
#    'ไหน',
#    'ความ',
#    'สำเร็จ',
#    'อยู่',
#    'ที่',
#    'นั้น'],
#   'pos'),
#  ([''], 'pos'),
#  (['สวย', 'รวย', 'เก่ง', 'ค่า', 'การ', 'ศึกษา'], 'pos'),
#  ([''], 'pos'),
#  (['น่า', 'อยู่', 'น่า', 'เที่ยว'], 'pos'),
#  ([''], 'pos'),
#  (['ข้อ', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['สะดวก', 'ง่าย', 'เข้าใจ', 'เร็ว', 'นึก', 'ออก', 'ง่าย'], 'pos'),
#  ([''], 'pos'),
#  (['ไม่', 'เสียใจ'], 'pos'),
#  ([''], 'pos'),
#  (['การ', 'ค้น', 'พบ', 'ที่', 'น่า', 'ตื่นเต้น', 'ที่สุด'], 'pos'),
#  ([''], 'pos'),
#  (['สบายใจ'], 'pos'),
#  ([''], 'pos'),
#  (['ชัดเจน'], 'pos'),
#  ([''], 'pos'),
#  (['ยัง', 'รอด', 'ชีวิต'], 'pos'),
#  ([''], 'pos'),
#  (['ถ่าย', 'ทำ', 'ได้', 'ดี', 'มากมุม', 'สวย'], 'pos'),
#  ([''], 'pos'),
#  (['มอง', 'เย็นใจ'], 'pos'),
#  ([''], 'pos'),
#  (['จังหวะ', 'ดี', 'ฝีมือ', 'เทพ', 'น่า', 'นับถือ'], 'pos'),
#  ([''], 'pos'),
#  (['นี้', 'ฟ้า', 'โปร่ง', 'สดใส'], 'pos'),
#  ([''], 'pos'),
#  (['เห็น', 'ชัดเจน'], 'pos'),
#  ([''], 'pos'),
#  (['ทัศนียภาพ', 'ตื่นตาตื่นใจ'], 'pos'),
#  ([''], 'pos'),
#  (['เพลิดเพลิน', 'ทิวทัศน์'], 'pos'),
#  ([''], 'pos'),
#  (['น่า', 'สนดี', 'เหมือน', 'แปลก', 'ใหม่', 'น่า', 'ท้าลอง'], 'pos'),
#  ([''], 'pos'),
#  (['กำลัง', 'กลับ', 'มา'], 'pos'),
#  ([''], 'pos'),
#  (['สุขสันต์เกิด'], 'pos'),
#  ([''], 'pos'),
#  (['สวัสดี', 'ปี', 'ใหม่'], 'pos'),
#  ([''], 'pos'),
#  (['รัก'], 'pos'),
#  ([''], 'pos'),
#  (['วิเศษ', 'รอย', 'ยิ้ม', 'สายตา', 'อบอุ่น'], 'pos'),
#  ([''], 'pos'),
#  (['ขอบคุณ', 'ทุก', 'ครั้ง', 'ที่', 'คอย', 'ปลอบ', 'ฉัน'], 'pos'),
#  ([''], 'pos'),
#  (['ชัดเจน', 'แค่', 'เห็น', 'ก็', 'ชื่นใจ'], 'pos'),
#  ([''], 'pos'),
#  (['ตื่นเต้น'], 'pos'),
#  ([''], 'pos'),
#  (['น่า', 'รัก', 'ที่สุด'], 'pos'),
#  ([''], 'pos'),
#  (['เข้าใจ', 'ตรง'], 'pos'),
#  ([''], 'pos'),
#  (['ความทรงจำ', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['คิด', 'ถึง', 'เหมือน'], 'pos'),
#  ([''], 'pos'),
#  (['ดวงดี'], 'pos'),
#  ([''], 'pos'),
#  (['ให้', 'โอกาส', 'แก้ตัว'], 'pos'),
#  ([''], 'pos'),
#  (['สอบ', 'ได้'], 'pos'),
#  ([''], 'pos'),
#  (['สอบ', 'ติด'], 'pos'),
#  ([''], 'pos'),
#  (['เย้ดีใจ', 'ด้วย'], 'pos'),
#  ([''], 'pos'),
#  (['อดทน', 'ไว้'], 'pos'),
#  ([''], 'pos'),
#  (['สิ่ง', 'ดีงาม', 'ควร', 'รักษา'], 'pos'),
#  ([''], 'pos'),
#  (['ความ', 'สุข', 'ง่าย', 'ขึ้น', 'อยู่ใจ'], 'pos'),
#  ([''], 'pos'),
#  (['อย่า', 'ทิ้งเค้า'], 'pos'),
#  ([''], 'pos'),
#  (['สำคัญ'], 'pos'),
#  ([''], 'pos'),
#  (['เข้มแข็ง', 'เข้า', 'ไว้', 'สู้'], 'pos'),
#  ([''], 'pos'),
#  (['เห็น', 'ด้วย'], 'pos'),
#  ([''], 'pos'),
#  (['พูดดี'], 'pos'),
#  ([''], 'pos'),
#  (['แคร์', 'ตัว', 'เอง'], 'pos'),
#  ([''], 'pos'),
#  (['บิน', 'ไป', 'ให้', 'ถึง', 'ฝัน'], 'pos'),
#  ([''], 'pos'),
#  (['การ', 'ทำ', 'ความ', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['ชนะใจ', 'ด้วย', 'การ', 'กระทำ'], 'pos'),
#  ([''], 'pos'),
#  (['ความ', 'สมบูรณ์แบบ'], 'pos'),
#  ([''], 'pos'),
#  (['ความ', 'สุข', 'ใน', 'ความ', 'คิด'], 'pos'),
#  ([''], 'pos'),
#  (['ชื่นชม', 'ทำ', 'ได้', 'ดี', 'มาก'], 'pos'),
#  ([''], 'pos'),
#  (['ปัง', 'มาก'], 'pos'),
#  ([''], 'pos'),
#  (['ดี',
#    'ช่วย',
#    'ที่',
#    'กำลัง',
#    'จะ',
#    'ตก',
#    'จาก',
#    'อาคาร',
#    'สูง',
#    'น่า',
#    'ชื่นชม'],
#   'pos'),
#  ([''], 'pos'),
#  (['ชอบ', 'ช่วยเหลือ', 'ผู้', 'อื่น'], 'pos'),
#  ([''], 'pos'),
#  (['มิตรภาพ', 'ที่', 'ดี', 'ที่สุด'], 'pos'),
#  ([''], 'pos'),
#  (['เชื่อมั่น', 'คุณธรรม', 'ความ', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['หอมน่า', 'กิน'], 'pos'),
#  ([''], 'pos'),
#  (['อยาก', 'รัก'], 'pos'),
#  ([''], 'pos'),
#  (['น่า', 'เรียนจัง'], 'pos'),
#  ([''], 'pos'),
#  (['น่า', 'กิน', 'น่า', 'อร่อย'], 'pos'),
#  ([''], 'pos'),
#  (['ยินดี', 'ที่', 'ได้', 'รู้จัก'], 'pos'),
#  ([''], 'pos'),
#  (['ใส่', 'บาตร', 'ทำ', 'บุญ'], 'pos'),
#  ([''], 'pos'),
#  (['นี้', 'ที่', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['สู้', 'ต่อ', 'ไป', 'สู้', 'ต่อ'], 'pos'),
#  ([''], 'pos'),
#  (['แคร์', 'ความ', 'รู้สึก'], 'pos'),
#  ([''], 'pos'),
#  (['เรา', 'โอเค'], 'pos'),
#  ([''], 'pos'),
#  (['ผูกพัน'], 'pos'),
#  ([''], 'pos'),
#  (['มากอด', 'มา'], 'pos'),
#  ([''], 'pos'),
#  (['สนใจ'], 'pos'),
#  ([''], 'pos'),
#  (['กำลังใจ'], 'pos'),
#  ([''], 'pos'),
#  (['สำคัญ', 'สุด'], 'pos'),
#  ([''], 'pos'),
#  (['ขอ', 'ข้า', 'รอง', 'พระบาททุก', 'ชาติ', 'ไป'], 'pos'),
#  ([''], 'pos'),
#  (['ไม่', 'ไหน', 'ไม่', 'คิด', 'ถึง'], 'pos'),
#  ([''], 'pos'),
#  (['เรา', 'รัก', 'ในหลวง'], 'pos'),
#  ([''], 'pos'),
#  (['อยาก', 'รู้จัก', 'จัง'], 'pos'),
#  ([''], 'pos'),
#  (['ยก', 'ความ', 'ดี', 'ความชอบ', 'ให้'], 'pos'),
#  ([''], 'pos'),
#  (['ช่วง', 'ที่', 'ดี', 'ที่สุด'], 'pos'),
#  ([''], 'pos'),
#  (['ไทย', 'ไม่', 'ทิ้ง', 'เร่ง', 'ช่วยเหลือ'], 'pos'),
#  ([''], 'pos'),
#  (['เหลือ', 'เชื่อ', 'มาก'], 'pos'),
#  ([''], 'pos'),
#  (['น่า', 'ตื่นเต้น', 'และ', 'ยิ่งใหญ่', 'มาก'], 'pos'),
#  ([''], 'pos'),
#  (['เจ๋ง', 'ไป'], 'pos'),
#  ([''], 'pos'),
#  (['ทำ', 'ทุก', 'อย่าง', 'เพื่อ', 'ปกป้อง', 'โลก'], 'pos'),
#  ([''], 'pos'),
#  (['อดใจ', 'รอ', 'ไม่', 'ไหว'], 'pos'),
#  ([''], 'pos'),
#  (['พอใจ', 'การ', 'ทำ', 'งาน'], 'pos'),
#  ([''], 'pos'),
#  (['ภาคภูมิใจ'], 'pos'),
#  ([''], 'pos'),
#  (['ศรัทธา'], 'pos'),
#  ([''], 'pos'),
#  (['เจริญเติบโต', 'อย่าง', 'แข็งแกร่ง', 'และ', 'สวยงาม'], 'pos'),
#  ([''], 'pos'),
#  (['ตอบแทน',
#    'ความ',
#    'หวัง',
#    'ดี',
#    'ด้วย',
#    'การ',
#    'ตั้งใจ',
#    'เรียน',
#    'ตั้งใจ',
#    'ทำ',
#    'งาน'],
#   'pos'),
#  ([''], 'pos'),
#  (['อยาก', 'กลับ', 'ไป', 'รื้อฟื้น', 'ความทรงจำ', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['พยายาม', 'สุด', 'ความ', 'สามารถ'], 'pos'),
#  ([''], 'pos'),
#  (['จะ', 'สู้', 'จนกว่า', 'จะ', 'ชนะ'], 'pos'),
#  ([''], 'pos'),
#  (['สนุก', 'มาก'], 'pos'),
#  ([''], 'pos'),
#  (['สนุกสนาน'], 'pos'),
#  ([''], 'pos'),
#  (['ฉัน',
#    'เคย',
#    'เกือบ',
#    'พลาด',
#    'สิ่ง',
#    'ที่',
#    'ดี',
#    'ที่สุด',
#    'ใน',
#    'ชีวิต'],
#   'pos'),
#  ([''], 'pos'),
#  (['ขอบคุณ', 'ที่รัก'], 'pos'),
#  ([''], 'pos'),
#  (['อย่า', 'ยอม', 'แพ้'], 'pos'),
#  ([''], 'pos'),
#  (['ถึง', 'เส้นชัย'], 'pos'),
#  ([''], 'pos'),
#  (['ชัยชนะ', 'สิ่ง', 'ที่', 'คุ้ม', 'ค่า'], 'pos'),
#  ([''], 'pos'),
#  (['อย่า', 'อ่อนแอ', 'แม้', 'จะ', 'ร้องไห้'], 'pos'),
#  ([''], 'pos'),
#  (['อย่า', 'อ่อนแอ', 'ร้องไห้', 'ไป', 'สู้'], 'pos'),
#  ([''], 'pos'),
#  (['ศรัทธา', 'ไม่', 'ท้อ'], 'pos'),
#  ([''], 'pos'),
#  (['อร่อย', 'ที่สุด', 'ใน', 'โลก'], 'pos'),
#  ([''], 'pos'),
#  (['จุดมุ่งหมาย', 'อัน', 'ทะเยอทะยาน'], 'pos'),
#  ([''], 'pos'),
#  (['เซอร์ไพรส์'], 'pos'),
#  ([''], 'pos'),
#  (['จะ', 'ไม่', 'ลืม', 'ดี', 'นี้'], 'pos'),
#  ([''], 'pos'),
#  (['สู้สู้'], 'pos'),
#  ([''], 'pos'),
#  (['นับ',
#    'ช่วง',
#    'ชีวิต',
#    'ที่',
#    'ดี',
#    'ที่สุด',
#    'แม้',
#    'แค่',
#    'เพียง',
#    'เวลา',
#    'สั้น'],
#   'pos'),
#  ([''], 'pos'),
#  (['มา', 'เชียร์', 'เพื่อน'], 'pos'),
#  ([''], 'pos'),
#  (['รัก', 'ให้', 'ทำ', 'ปากจู๋', 'ขอ', 'หัวใจ', 'ละ', 'ดวง', 'จุ้บ'], 'pos'),
#  ([''], 'pos'),
#  (['พยายาม', 'แบ๊ว'], 'pos'),
#  ([''], 'pos'),
#  (['ดี', 'ที่สุด'], 'pos'),
#  ([''], 'pos'),
#  (['ขอ', 'กำลังใจ', 'หน่อย'], 'pos'),
#  ([''], 'pos'),
#  (['ทุก', 'พูด', 'ความ', 'จริง'], 'pos'),
#  ([''], 'pos'),
#  (['เธอ', 'น่า', 'รัก', 'จังทำ', 'ให้', 'ใจเซ'], 'pos'),
#  ([''], 'pos'),
#  (['กล้อง', 'ของ', 'ที่', 'สวยงาม'], 'pos'),
#  ([''], 'pos'),
#  (['ข่าว', 'ดี', 'มา', 'บอก'], 'pos'),
#  ([''], 'pos'),
#  (['น่า', 'รัก', 'แถม', 'ความ', 'รู้', 'ด้วย', 'สนใจ', 'ป่าว'], 'pos'),
#  ([''], 'pos'),
#  (['เธอ', 'เรียบร้อย'], 'pos'),
#  ([''], 'pos'),
#  (['ชอบ', 'จิตใจ', 'ดี', 'และ', 'ขยัน', 'มาก', 'กว่า'], 'pos'),
#  ([''], 'pos'),
#  (['ปรบ', 'มือ', 'ตาม', 'ระเบียบ'], 'pos'),
#  ([''], 'pos'),
#  (['น้ำใจ', 'นัก', 'กีฬา'], 'pos'),
#  ([''], 'pos'),
#  (['ปลอด', 'ภัย', 'ไว้', 'ก่อน', 'ป้องกัน', 'ไว้'], 'pos'),
#  ([''], 'pos'),
#  (['เข้าใจ', 'ง่าย', 'สะดวก', 'รวดเร็ว'], 'pos'),
#  ([''], 'pos'),
#  (['คุณค่า', 'ที่', 'คู่', 'ควร'], 'pos'),
#  ([''], 'pos'),
#  (['น่า', 'รัก', 'อ่ะ', 'อยาก', 'เดิน', 'จับ', 'มือ', 'ไป', 'จน', 'แก่'],
#   'pos'),
#  ([''], 'pos'),
#  (['ว้อน', 'อยาก', 'ได้'], 'pos'),
#  ([''], 'pos'),
#  (['ไม่', 'อด', 'ตาย'], 'pos'),
#  ([''], 'pos'),
#  (['สนับสนุน', 'ส่งเสริม', 'ความ', 'สามัคคี'], 'pos'),
#  ([''], 'pos'),
#  (['อยู่', 'ไหน', 'ก็', 'รัก', 'เหมือน', 'เดิม'], 'pos'),
#  ([''], 'pos'),
#  (['ขอ', 'กอด', 'หน่อย'], 'pos'),
#  ([''], 'pos'),
#  (['ดีเนาะ'], 'pos'),
#  ([''], 'pos'),
#  (['ฝัน', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['ของ', 'อร่อยน่า', 'กิน'], 'pos'),
#  ([''], 'pos'),
#  (['เห็น', 'ด้วย'], 'pos'),
#  ([''], 'pos'),
#  (['ดี', 'ต่อ', 'ใจ'], 'pos'),
#  ([''], 'pos'),
#  (['ประหยัด'], 'pos'),
#  ([''], 'pos'),
#  (['เชียร์'], 'pos'),
#  ([''], 'pos'),
#  (['สดใส'], 'pos'),
#  ([''], 'pos'),
#  (['เก่ง', 'ขึ้น', 'มาก'], 'pos'),
#  ([''], 'pos'),
#  (['ขอบคุณ', 'ที่', 'ติดตาม'], 'pos'),
#  ([''], 'pos'),
#  (['ฝีมือ', 'พัฒนา', 'เร็ว', 'มาก'], 'pos'),
#  ([''], 'pos'),
#  (['คำ', 'พูด', 'หวานหวาน'], 'pos'),
#  ([''], 'pos'),
#  (['หวาน', 'น่า', 'กิน'], 'pos'),
#  ([''], 'pos'),
#  (['จีบ', 'หวาน'], 'pos'),
#  ([''], 'pos'),
#  (['คบ', 'ไหม'], 'pos'),
#  ([''], 'pos'),
#  (['แอบ', 'รัก'], 'pos'),
#  ([''], 'pos'),
#  (['คาดหวัง'], 'pos'),
#  ([''], 'pos'),
#  (['เขิน'], 'pos'),
#  ([''], 'pos'),
#  (['เพื่อน', 'รัก'], 'pos'),
#  ([''], 'pos'),
#  (['ได้', 'ฉัน', 'ก็ได้'], 'pos'),
#  ([''], 'pos'),
#  (['ฝึกฝน', 'จน', 'เก่ง'], 'pos'),
#  ([''], 'pos'),
#  (['ชอบ', 'ความ', 'รู้สึก', 'แบบ', 'นี้', 'น่ะ'], 'pos'),
#  ([''], 'pos'),
#  (['ตั้ง', 'เเต่', 'เรา', 'คุย', 'เหมือน', 'เรา', 'เจอ', 'มาก', 'ขึ้น'],
#   'pos'),
#  ([''], 'pos'),
#  (['ให้', 'นึก', 'ถึง'], 'pos'),
#  ([''], 'pos'),
#  (['เชื่อมั่น', 'ใน', 'ตน', 'เอง'], 'pos'),
#  ([''], 'pos'),
#  (['แรง', 'บันดาลใจ', 'ให้', 'ใฝ่', 'เรียน'], 'pos'),
#  ([''], 'pos'),
#  (['ห่วง', 'เสมอ'], 'pos'),
#  ([''], 'pos'),
#  (['ได้', 'ฟัง', 'เพลง', 'ที่', 'ชอบ'], 'pos'),
#  ([''], 'pos'),
#  (['แบบ',
#    'โมเม้น',
#    'ที่',
#    'ความ',
#    'รัก',
#    'รัก',
#    'เรา',
#    'ทำ',
#    'อะไร',
#    'ซัก',
#    'อย่าง',
#    'ให้',
#    'เรา',
#    'มั่นใจ',
#    'แบบ',
#    'นี้',
#    'ได้',
#    'โคตรปลื้มใจ'],
#   'pos'),
#  ([''], 'pos'),
#  (['ถึงแพ้', 'ก็', 'จะ', 'ไม่', 'ยอม', 'ถอย'], 'pos'),
#  ([''], 'pos'),
#  (['ลา', 'ก่อน', 'เดี๋ยว', 'ได้', 'เจอ', 'อีก'], 'pos'),
#  ([''], 'pos'),
#  (['สู้', 'ไม่', 'ถอย'], 'pos'),
#  ([''], 'pos'),
#  (['จุดหมาย', 'ไม่', 'ไกล', 'เกิน', 'จริง'], 'pos'),
#  ([''], 'pos'),
#  (['ตาม', 'ทัน'], 'pos'),
#  ([''], 'pos'),
#  (['มั่นคง'], 'pos'),
#  ([''], 'pos'),
#  (['สุขใจ', 'ขอบคุณ', 'เวลา'], 'pos'),
#  ([''], 'pos'),
#  (['คุย', 'ได้'], 'pos'),
#  ([''], 'pos'),
#  (['ความ', 'รู้สึก', 'ไว้เติมใจ'], 'pos'),
#  ([''], 'pos'),
#  (['ขอบใจ'], 'pos'),
#  ([''], 'pos'),
#  (['ขาย', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['ไว้', 'เจอ', 'อีก', 'ที', 'ใน', 'เวลา', 'ที่', 'เหมาะสม'], 'pos'),
#  ([''], 'pos'),
#  (['รัก', 'อยู่', 'เคียงข้าง', 'เสมอ'], 'pos'),
#  ([''], 'pos'),
#  (['แฮปปี้', 'ความ', 'สุข', 'รัก', 'เสมอ'], 'pos'),
#  ([''], 'pos'),
#  (['ชม', 'ว่า', 'สวย', 'ขึ้น', 'น่า', 'รัก', 'ขึ้น'], 'pos'),
#  ([''], 'pos'),
#  (['ของ', 'น่า', 'รัก'], 'pos'),
#  ([''], 'pos'),
#  (['บรรยากาศ', 'ดี', 'สีสัน'], 'pos'),
#  ([''], 'pos'),
#  (['ของ', 'โปรด'], 'pos'),
#  ([''], 'pos'),
#  (['สวรรค์'], 'pos'),
#  ([''], 'pos'),
#  (['เพราะ', 'จัง'], 'pos'),
#  ([''], 'pos'),
#  (['เพลง', 'ไพเราะ', 'มาก'], 'pos'),
#  ([''], 'pos'),
#  (['พรวิเศษ'], 'pos'),
#  ([''], 'pos'),
#  (['เรื่อง', 'น่า', 'ยินดีใจ', 'มาก'], 'pos'),
#  ([''], 'pos'),
#  (['กล้าหาญ'], 'pos'),
#  ([''], 'pos'),
#  (['การันตี'], 'pos'),
#  ([''], 'pos'),
#  (['อนุมัติ'], 'pos'),
#  ([''], 'pos'),
#  (['ตัดสินใจ', 'ได้', 'เด็ดขาด'], 'pos'),
#  ([''], 'pos'),
#  (['ตัดสิน', 'คดี', 'อย่าง', 'ยุติธรรม'], 'pos'),
#  ([''], 'pos'),
#  (['อนุญาต', 'ให้', 'เข้า', 'มา', 'ได้'], 'pos'),
#  ([''], 'pos'),
#  (['รักษ์โลก', 'รักษ์', 'สิ่งแวดล้อม'], 'pos'),
#  ([''], 'pos'),
#  (['ง่าย', 'ที่', 'ใคร', 'ก็', 'ทำ', 'ได้'], 'pos'),
#  ([''], 'pos'),
#  (['ออก', 'กำลัง', 'กาย'], 'pos'),
#  ([''], 'pos'),
#  (['รีไซเคิล', 'นำ', 'กลับ', 'มา', 'ใช้', 'ใหม่', 'ลด', 'โลก', 'ร้อน'], 'pos'),
#  ([''], 'pos'),
#  (['ช่วย',
#    'ลด',
#    'โลก',
#    'ร้อน',
#    'ด้วย',
#    'การ',
#    'รณรงค์',
#    'ร่วม',
#    'มือ',
#    'ลด',
#    'มลพิษ'],
#   'pos'),
#  ([''], 'pos'),
#  (['อยู่', 'อย่าง', 'พอเพียง', 'ปลูก', 'ผัก', 'ปลอด', 'สาร', 'พิษ'], 'pos'),
#  ([''], 'pos'),
#  (['โอเะไม่', 'เสียใจ'], 'pos'),
#  ([''], 'pos'),
#  (['สร้าง', 'สันติภาพ'], 'pos'),
#  ([''], 'pos'),
#  (['จง',
#    'นับถือ',
#    'ตัว',
#    'เอง',
#    'ให้',
#    'มาก',
#    'พอ',
#    'ที่',
#    'จะ',
#    'รู้',
#    'ว่า',
#    'คู่',
#    'ควร',
#    'สิ่ง',
#    'ที่',
#    'ดี',
#    'ที่สุด'],
#   'pos'),
#  ([''], 'pos'),
#  (['ความ',
#    'ท้าทาย',
#    'สิ่ง',
#    'ที่',
#    'ทำ',
#    'ให้',
#    'ชีวิต',
#    'น่า',
#    'สนใจ',
#    'แต่',
#    'การ',
#    'เอา',
#    'ชนะ',
#    'ให้',
#    'ได้',
#    'สิ่ง',
#    'ที่',
#    'ทำ',
#    'ให้',
#    'ชีวิต',
#    'ความหมาย'],
#   'pos'),
#  ([''], 'pos'),
#  (['อนาคต',
#    'ของ',
#    'ขึ้น',
#    'อยู่',
#    'สิ่ง',
#    'ที่',
#    'ทำ',
#    'ใน',
#    'นี้',
#    'ไม่',
#    'ใช่',
#    'พรุ่ง',
#    'นี้'],
#   'pos'),
#  ([''], 'pos'),
#  (['อย่า',
#    'เพิ่ง',
#    'ยอม',
#    'แพ้',
#    'จุด',
#    'เริ่มต้น',
#    'นั้น',
#    'มัก',
#    'จะ',
#    'ยาก',
#    'ที่สุด',
#    'เสมอ'],
#   'pos'),
#  ([''], 'pos'),
#  (['สิ่ง',
#    'เดียว',
#    'ที่',
#    'แน่นอน',
#    'ที่สุด',
#    'ใน',
#    'ชีวิต',
#    'คือ',
#    'ความ',
#    'เปลี่ยนแปลง'],
#   'pos'),
#  ([''], 'pos'),
#  (['ความ', 'รัก', 'ชนะ', 'ความ', 'รัก', 'ความ', 'สงบสุข'], 'pos'),
#  ([''], 'pos'),
#  (['ทุก',
#    'ที่',
#    'ประสบ',
#    'ชัยชนะ',
#    'ใน',
#    'สิ่ง',
#    'ใด',
#    'ที่',
#    'ทำ',
#    'ต้อง',
#    'เต็มใจ',
#    'ตั้งใจ'],
#   'pos'),
#  ([''], 'pos'),
#  (['ความ', 'ปรารถนา', 'อัน', 'ร้อน', 'แรง', 'ชัยชนะ', 'ความ', 'สำเร็จ'],
#   'pos'),
#  ([''], 'pos'),
#  (['จง',
#    'แน่วแน่',
#    'ใน',
#    'การ',
#    'ตัดสินใจ',
#    'แต่',
#    'ให้',
#    'ยืดหยุ่น',
#    'การ',
#    'ลงมือ',
#    'ทำ'],
#   'pos'),
#  ([''], 'pos'),
#  (['ความ',
#    'มั่นใจ',
#    'มา',
#    'จาก',
#    'การ',
#    'ไม่',
#    'กลัว',
#    'ที่',
#    'จะ',
#    'ทำ',
#    'อะไร',
#    'ผิด'],
#   'pos'),
#  ([''], 'pos'),
#  (['วิธี',
#    'ให้',
#    'กำลังใจ',
#    'ตัว',
#    'เอง',
#    'ที่',
#    'ดี',
#    'ที่สุด',
#    'คือ',
#    'การ',
#    'ให้',
#    'กำลังใจ',
#    'อื่น'],
#   'pos'),
#  ([''], 'pos'),
#  (['ก็', 'ได้', 'ค้น', 'พบ', 'ตัว', 'เอง'], 'pos'),
#  ([''], 'pos'),
#  (['สิ่ง', 'นี้', 'เกิด', 'ขึ้น', 'จาก', 'แรง', 'บันดาลใจ'], 'pos'),
#  ([''], 'pos'),
#  (['ไตร่ตรอง', 'และ', 'มอง', 'ด้าน', 'บวก', 'เข้า', 'ไว้'], 'pos'),
#  ([''], 'pos'),
#  (['การ',
#    'เริ่มต้น',
#    'ทำ',
#    'สิ่ง',
#    'เดิม',
#    'อีก',
#    'ครั้ง',
#    'อย่าง',
#    'ชาญฉลาด',
#    'กว่า',
#    'เดิม'],
#   'pos'),
#  ([''], 'pos'),
#  (['ฮาขำ'], 'pos'),
#  ([''], 'pos'),
#  (['ราตรีสวัสดิ์'], 'pos'),
#  ([''], 'pos'),
#  (['กล้า', 'คิด', 'กล้า', 'ทำ'], 'pos'),
#  ([''], 'pos'),
#  (['ทำ', 'ความ', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['เธอ', 'คือ', 'ทุก', 'อย่าง', 'ใน', 'ชีวิต'], 'pos'),
#  ([''], 'pos'),
#  (['สดชื่นใจ', 'อากาศ', 'ดี', 'นี้'], 'pos'),
#  ([''], 'pos'),
#  (['อีก', 'ไม่', 'นาน', 'เกิน', 'รอ', 'ทุก', 'อย่าง', 'จะ', 'ดี', 'ขึ้น'],
#   'pos'),
#  ([''], 'pos'),
#  (['สัญญา', 'ว่า', 'รัก', 'เธอ', 'เดียว'], 'pos'),
#  ([''], 'pos'),
#  (['แน่ใจ', 'ว่า', 'ทำ', 'ได้', 'แน่นอน'], 'pos'),
#  ([''], 'pos'),
#  (['สอบ', 'ผ่าน'], 'pos'),
#  ([''], 'pos'),
#  (['รัก', 'เสมอ'], 'pos'),
#  ([''], 'pos'),
#  (['ของขวัญ', 'ที่', 'ค่า'], 'pos'),
#  ([''], 'pos'),
#  (['สมหวัง', 'ทุก', 'ประการ'], 'pos'),
#  ([''], 'pos'),
#  (['อยาก',
#    'ให้',
#    'เธอ',
#    'อยู่',
#    'เคียงข้าง',
#    'ฉัน',
#    'อย่าง',
#    'นี้',
#    'ทุก',
#    'คืน',
#    'อย่าง',
#    'นี้',
#    'ตลอด',
#    'ไป'],
#   'pos'),
#  ([''], 'pos'),
#  (['พร้อม', 'ที่', 'จะ', 'เผชิญ', 'ความ', 'จริง'], 'pos'),
#  ([''], 'pos'),
#  (['รูป', 'นี้', 'รู้สึก', 'อบอุ่น'], 'pos'),
#  ([''], 'pos'),
#  (['อย่าง', 'น้อย', 'สนใจ'], 'pos'),
#  ([''], 'pos'),
#  (['ยิ้ม'], 'pos'),
#  ([''], 'pos'),
#  (['กำลังใจ'], 'pos'),
#  ([''], 'pos'),
#  (['ฝัน'], 'pos'),
#  ([''], 'pos'),
#  (['แรงใจ'], 'pos'),
#  ([''], 'pos'),
#  (['ดวงใจ', 'ลุกโชน', 'ความ', 'หวัง'], 'pos'),
#  ([''], 'pos'),
#  (['แสงง', 'สว่าง', 'ส่องใจ'], 'pos'),
#  ([''], 'pos'),
#  (['การ',
#    'ชำระ',
#    'จิต',
#    'หรือ',
#    'ใจ',
#    'ให้',
#    'ผ่องใส',
#    'สิ่ง',
#    'สำคัญ',
#    'ที่สุด',
#    'ที่',
#    'พึ่ง',
#    'ปรารถนา',
#    'ที่สุด',
#    'ของ',
#    'ผู้',
#    'ปัญญา',
#    'ทั้งหลาย'],
#   'pos'),
#  ([''], 'pos'),
#  (['ทำ', 'จิต', 'ให้', 'สงบ', 'จะ', 'พบ', 'ทาง', 'ออก'], 'pos'),
#  ([''], 'pos'),
#  (['ความ', 'พร้อม', 'อยู่', 'ที่', 'เรา'], 'pos'),
#  ([''], 'pos'),
#  (['ลงมือ', 'ทำ', 'อย่าง', 'ต่อเนื่อง', 'เท่า', 'นั้น', 'เอง'], 'pos'),
#  ([''], 'pos'),
#  (['ไม่', 'ถูก', 'ตัว', 'เอง'], 'pos'),
#  ([''], 'pos'),
#  (['ต้อง',
#    'เชื่อ',
#    'ใน',
#    'ศักยาภาพ',
#    'ของ',
#    'คุณ',
#    'และ',
#    'ความ',
#    'พยายาม',
#    'ที่'],
#   'pos'),
#  ([''], 'pos'),
#  (['นี่', 'สิ่ง', 'ล้ำ', 'ค่า'], 'pos'),
#  ([''], 'pos'),
#  (['ห่วงใย'], 'pos'),
#  ([''], 'pos'),
#  (['สันติภาพ', 'สิ่ง', 'ที่', 'คาดหวัง'], 'pos'),
#  ([''], 'pos'),
#  (['หยิบ', 'ยื่น', 'โอกาส'], 'pos'),
#  ([''], 'pos'),
#  (['สาน', 'ต่อ', 'ความ', 'ฝัน', 'ให้', 'จริง'], 'pos'),
#  ([''], 'pos'),
#  (['ไม่', 'ต้อง', 'กังวลใจ'], 'pos'),
#  ([''], 'pos'),
#  (['มอง', 'โลก', 'ใน', 'แง่', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['ทำ', 'ได้', 'ดี', 'กว่า', 'นี้', 'อีก'], 'pos'),
#  ([''], 'pos'),
#  (['อยาก', 'ให้', 'อ่าน', 'กำลังใจ', 'ขึ้น'], 'pos'),
#  ([''], 'pos'),
#  (['อดทน', 'รอฟ้าใส'], 'pos'),
#  ([''], 'pos'),
#  (['เจอ',
#    'ที่',
#    'ใช่',
#    'และ',
#    'พร้อม',
#    'ฝ่า',
#    'ฟัน',
#    'ทุก',
#    'อย่าง',
#    'ไป',
#    'เรา'],
#   'pos'),
#  ([''], 'pos'),
#  (['เดิน', 'สาย', 'ปฎิบัติธรรม', 'ไป', 'วัด', 'ทำ', 'บุญ'], 'pos'),
#  ([''], 'pos'),
#  (['พบ', 'มุมมอง', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['ที่ปรึกษา', 'ที่', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['ผ่าน', 'สัมภาษณ์'], 'pos'),
#  ([''], 'pos'),
#  (['ปรับปรุง'], 'pos'),
#  ([''], 'pos'),
#  (['ที่', 'ยึดเหนี่ยวทางใจ'], 'pos'),
#  ([''], 'pos'),
#  (['ทัศนคติ', 'ที่', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['แนวทาง', 'แก้', 'ปัญหา'], 'pos'),
#  ([''], 'pos'),
#  (['มอง', 'โลก', 'กว้าง'], 'pos'),
#  ([''], 'pos'),
#  (['ศักดิ์ศรี'], 'pos'),
#  ([''], 'pos'),
#  (['ไม่', 'เลื่อน', 'หาย'], 'pos'),
#  ([''], 'pos'),
#  (['ความ', 'รวม', 'น้ำใจ', 'รวม', 'พลัง'], 'pos'),
#  ([''], 'pos'),
#  (['คุณภาพ', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['ขอ', 'ให้', 'ปราถนา', 'ที่', 'ตั้งใจ', 'ไว้', 'ด้วย'], 'pos'),
#  ([''], 'pos'),
#  (['ยิ้ม', 'รอ', 'ดี', 'กว่า'], 'pos'),
#  ([''], 'pos'),
#  (['ทำ',
#    'ให้',
#    'ศรัทธา',
#    'ที่',
#    'จะ',
#    'รำลึก',
#    'ถึง',
#    'พระ',
#    'เพื่อ',
#    'ดำรง',
#    'พระศาสนา',
#    'ให้',
#    'ยืนนานสาธุ'],
#   'pos'),
#  ([''], 'pos'),
#  (['สาธุ', 'คำ', 'สอน', 'ที่', 'ตรง', 'และ', 'ถูกต้อง', 'ที่สุด'], 'pos'),
#  ([''], 'pos'),
#  (['ประพฤติ', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['เอง'], 'pos'),
#  ([''], 'pos'),
#  (['ให้', 'ข้อคิด', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['บุญกุศล'], 'pos'),
#  ([''], 'pos'),
#  (['รัก', 'เสมือน', 'พี่น้อง'], 'pos'),
#  ([''], 'pos'),
#  (['ชนะ', 'เลิศ'], 'pos'),
#  ([''], 'pos'),
#  (['ได้', 'รางวัล', 'เหรียญ', 'ทอง'], 'pos'),
#  ([''], 'pos'),
#  (['ให้', 'อภัย'], 'pos'),
#  ([''], 'pos'),
#  (['รักษา', 'โรค'], 'pos'),
#  ([''], 'pos'),
#  (['เข้าใจ', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['ทำ', 'ให้', 'ดี', 'กว่า', 'เดิม'], 'pos'),
#  ([''], 'pos'),
#  (['เบิกบาน'], 'pos'),
#  ([''], 'pos'),
#  (['เชิดชู'], 'pos'),
#  ([''], 'pos'),
#  (['เชิดหน้าชูตา'], 'pos'),
#  ([''], 'pos'),
#  (['สามัคคี', 'หนึ่ง', 'เดียว'], 'pos'),
#  ([''], 'pos'),
#  (['เกียรติยศ'], 'pos'),
#  ([''], 'pos'),
#  (['การ', 'กุศล'], 'pos'),
#  ([''], 'pos'),
#  (['คึกครื้น'], 'pos'),
#  ([''], 'pos'),
#  (['เตรียม', 'ตัว', 'ให้', 'พร้อม'], 'pos'),
#  ([''], 'pos'),
#  (['เสรีภาพ', 'บน', 'เสรีประชาธิปไตย'], 'pos'),
#  ([''], 'pos'),
#  (['คุ้มค่า'], 'pos'),
#  ([''], 'pos'),
#  (['สุภาพ', 'เรียบร้อย'], 'pos'),
#  ([''], 'pos'),
#  (['ขัดขืน', 'ต่อสู้', 'เพื่อ', 'ป้องกัน', 'ตัว', 'เอง'], 'pos'),
#  ([''], 'pos'),
#  (['ประทับใจ'], 'pos'),
#  ([''], 'pos'),
#  (['สาระ', 'ประโยชน์'], 'pos'),
#  ([''], 'pos'),
#  (['กลับ', 'ตัว', 'กลับใจ', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['ได้', 'กำไร'], 'pos'),
#  ([''], 'pos'),
#  (['คลี่คลาย'], 'pos'),
#  ([''], 'pos'),
#  (['โล่งใจ'], 'pos'),
#  ([''], 'pos'),
#  (['รวดเร็ว', 'ทันใจ'], 'pos'),
#  ([''], 'pos'),
#  (['ใจเย็น'], 'pos'),
#  ([''], 'pos'),
#  (['ตอกย้ำ', 'ความทรงจำ', 'ดี'], 'pos'),
#  ([''], 'pos'),
#  (['หวานใจ'], 'pos'),
#  ([''], 'pos'),
#  (['เมตตาปราณี'], 'pos'),
#  ([''], 'pos'),
#  (['พัฒนา', 'ตน', 'เอง', 'สม่ำเสมอ', 'ด้วย', 'ความ', 'ไม่', 'ย่อท้อ'], 'pos'),
#  ([''], 'pos'),
#  (['สาน', 'ฝัน', 'ให้', 'จริง'], 'pos'),
#  ([''], 'pos'),
#  (['อาสา'], 'pos'),
#  ([''], 'pos'),
#  (['อยาก', 'กอด'], 'pos'),
#  ([''], 'pos'),
#  (['เตือน', 'สติ'], 'pos'),
#  ([''], 'pos'),
#  (['สันติสุข'], 'pos'),
#  ([''], 'pos'),
#  (['สำนึก'], 'pos'),
#  ([''], 'pos'),
#  (['เลือก', 'ตามใจ'], 'pos'),
#  ([''], 'pos'),
#  (['โครตน่ารัก'], 'pos'),
#  ([''], 'pos'),
#  (['มหัศจรรย์'], 'pos'),
#  ([''], 'pos'),
#  (['สิ่งพิเศษ'], 'pos'),
#  ([''], 'pos'),
#  (['วิเศษ'], 'pos'),
#  ([''], 'pos'),
#  (['ผ่อนคลาย'], 'pos'),
#  ([''], 'pos'),
#  (['ยอมรับ'], 'pos'),
#  ([''], 'pos'),
#  (['เจริญรุ่งเรือง'], 'pos'),
#  ([''], 'pos'),
#  (['เสียสละ'], 'pos'),
#  ([''], 'pos'),
#  (['ไถ่โทษ'], 'pos'),
#  ([''], 'pos'),
#  (['ไถ่บาป'], 'pos'),
#  ([''], 'pos'),
#  (['อบอวล'], 'pos'),
#  ([''], 'pos'),
#  (['สะอาด'], 'pos'),
#  ([''], 'pos'),
#  (['เอาใจใส่'], 'pos'),
#  ([''], 'pos'),
#  (['ภาวนา'], 'pos'),
#  ([''], 'pos'),
#  (['ฟุ้งเฟื่อง'], 'pos'),
#  ([''], 'pos'),
#  (['เกียรติคุณ'], 'pos'),
#  ([''], 'pos'),
#  (['ด้าน', 'บวก'], 'pos'),
#  ([''], 'pos'),
#  (['ปลื้ม', 'ดีใจ'], 'pos'),
#  ([''], 'pos'),
#  (['คึกคัก'], 'pos'),
#  ([''], 'pos'),
#  (['เจตนาดี'], 'pos'),
#  ([''], 'pos'),
#  (['จิตแจ่มใส'], 'pos'),
#  ([''], 'pos'),
#  (['เปรี้ยง', 'ปร้าง'], 'pos'),
#  ([''], 'pos'),
#  (['ฮิต'], 'pos'),
#  ([''], 'pos'),
#  (['ที่', 'นิยม'], 'pos'),
#  ([''], 'pos'),
#  (['ปลอบใจ'], 'pos'),
#  ([''], 'pos'),
#  (['ปรองดอง'], 'pos'),
#  ([''], 'pos'),
#  (['ไมตรี'], 'pos'),
#  ([''], 'pos'),
#  (['มารยาท'], 'pos'),
#  ([''], 'pos'),
#  (['รอบคอบ'], 'pos'),
#  ([''], 'pos'),
#  (['บริสุทธิ์ใจ'], 'pos'),
#  ([''], 'pos'),
#  (['เคารพนับถือ'], 'pos'),
#  ([''], 'pos'),
#  (['วุฒิภาวะ'], 'pos'),
#  ([''], 'pos'),
#  (['สุขุม'], 'pos'),
#  ([''], 'pos'),
#  (['ฟื้นฟู'], 'pos'),
#  ([''], 'pos'),
#  (['ล้ำสมัย'], 'pos'),
#  ([''], 'pos'),
#  (['ดี', 'ที่สุด'], 'pos'),
#  ([''], 'pos'),
#  (['ทัน', 'เวลา', 'พอดี'], 'pos'),
#  ([''], 'pos'),
#  (['สุจริต'], 'pos'),
#  ([''], 'pos'),
#  (['น่า', 'เชื่อถือ'], 'pos'),
#  ([''], 'pos'),
#  (['เท่ห์'], 'pos'),
#  ([''], 'pos'),
#  (['ไว้วางใจ'], 'pos'),
#  ([''], 'pos'),
#  (['เสน่ห์'], 'pos'),
#  ([''], 'pos'),
#  (['ทรง', 'พลัง'], 'pos'),
#  ([''], 'pos'),
#  (['ฮัก'], 'pos'),
#  ([''], 'pos'),
#  (['ทุ่มเท'], 'pos'),
#  ([''], 'pos'),
#  (['ภักดี'], 'pos'),
#  ([''], 'pos'),
#  (['งอกงาม'], 'pos'),
#  ([''], 'pos'),
#  (['คุ้มครอง'], 'pos'),
#  ([''], 'pos'),
#  (['พึ่งพา'], 'pos'),
#  ([''], 'pos'),
#  (['พึ่งพิง'], 'pos'),
#  ([''], 'pos'),
#  (['ยิ้มแย้ง'], 'pos'),
#  ([''], 'pos'),
#  (['ประเสริฐ'], 'pos'),
#  ([''], 'pos'),
#  (['คลี่คลาย'], 'pos'),
#  ([''], 'pos'),
#  (['เที่ยงธรรม'], 'pos'),
#  ([''], 'pos'),
#  (['ชดเชย'], 'pos'),
#  ([''], 'pos'),
#  (['เอื้อเฟื้อ', 'เผื่อแผ่'], 'pos'),
#  ([''], 'pos'),
#  (['เยียวยา'], 'pos'),
#  ([''], 'pos'),
#  (['คล่อง', 'ตัว'], 'pos'),
#  ([''], 'pos'),
#  (['คล่องแคล่ว'], 'pos'),
#  ([''], 'pos'),
#  (['อุทิศ'], 'pos'),
#  ([''], 'pos'),
#  (['เอ็นดู'], 'pos'),
#  ([''], 'pos'),
#  (['เพียงพอ'], 'pos'),
#  ([''], 'pos'),
#  (['เพลิดเพลิน'], 'pos'),
#  ([''], 'pos'),
#  (['ถูกใจ'], 'pos'),
#  ([''], 'pos'),
#  (['ไลค์'], 'pos'),
#  ([''], 'pos'),
#  (['อลังการ'], 'pos'),
#  ([''], 'pos'),
#  (['ว้าย'], 'pos'),
#  (['ไม่'], 'neg'),
#  ([''], 'neg'),
#  (['ไม่', 'เรื่อง'], 'neg'),
#  ([''], 'neg'),
#  (['ทำ', 'กลับ', 'ไม่'], 'neg'),
#  ([''], 'neg'),
#  (['ช่าง', 'เลว', 'จริง', 'ๆ'], 'neg'),
#  ([''], 'neg'),
#  (['ผล', 'งาน', 'ย่ำแย่', 'จน', 'ใกล้', 'ตก', 'ชั้น'], 'neg'),
#  ([''], 'neg'),
#  (['อึดอัด', 'ไม่รัก'], 'neg'),
#  ([''], 'neg'),
#  (['ปวด', 'หัว', 'แท้ล้า'], 'neg'),
#  ([''], 'neg'),
#  (['ไม่', 'เงิน', 'โว้ย'], 'neg'),
#  ([''], 'neg'),
#  (['ขี้', 'เกียจ', 'ล้าน', 'ตัว'], 'neg'),
#  ([''], 'neg'),
#  (['แย่', 'ว่ะ'], 'neg'),
#  ([''], 'neg'),
#  (['ทำ', 'ไม่', 'วะ'], 'neg'),
#  ([''], 'neg'),
#  (['ไม่', 'ชอบ'], 'neg'),
#  ([''], 'neg'),
#  (['ร้อน', 'ตัว', 'หรอ'], 'neg'),
#  ([''], 'neg'),
#  (['ไม่', 'น่า', 'รัก'], 'neg'),
#  ([''], 'neg'),
#  (['อำลา', 'นี้', 'ไม่', 'เจอ', 'อีก', 'น่ะ'], 'neg'),
#  ([''], 'neg'),
#  (['เวลา', 'เหนื่อย', 'นี่', 'บ่น', 'ใคร', 'บ้าง'], 'neg'),
#  ([''], 'neg'),
#  (['เสีย'], 'neg'),
#  ([''], 'neg'),
#  (['เสีย', 'ความ', 'รู้สึก'], 'neg'),
#  ([''], 'neg'),
#  (['นก', 'บ่อย', 'ขนาด', 'นี้', 'ควร', 'ไป', 'ตาย', 'เกิด', 'ใหม่', 'เถอะ'],
#   'neg'),
#  ([''], 'neg'),
#  (['เจ็บ', 'เจ็บ', 'อีก'], 'neg'),
#  ([''], 'neg'),
#  (['อิจฉาจัง'], 'neg'),
#  ([''], 'neg'),
#  (['ไม่', 'ต่าง', 'สัตว์', 'เดรัจฉาน'], 'neg'),
#  ([''], 'neg'),
#  (['หยัง', 'อาย', 'คิด', 'อาย'], 'neg'),
#  ([''], 'neg'),
#  (['ทุเรศ'], 'neg'),
#  ([''], 'neg'),
#  (['ลั่น', 'เบศพ'], 'neg'),
#  ([''], 'neg'),
#  (['ทุเรดสุด'], 'neg'),
#  ([''], 'neg'),
#  (['แบล็กลิสต์'], 'neg'),
#  ([''], 'neg'),
#  (['เพ้อเจ้อกคิด', 'ไป', 'เอง', 'มโน', 'ไป', 'เอง'], 'neg'),
#  ([''], 'neg'),
#  (['ไม่', 'ซาบซึ้ง'], 'neg'),
#  ([''], 'neg'),
#  (['ถูก', 'ทัณฑ์', 'ทรน', 'แห่ง', 'นรก'], 'neg'),
#  ([''], 'neg'),
#  (['ข่มขู่', 'บีบบังคับ'], 'neg'),
#  ([''], 'neg'),
#  (['เดี่ยว', 'เสีย', 'ที', 'หลัง'], 'neg'),
#  ([''], 'neg'),
#  (['เธอ', 'มอง', 'ข้าม'], 'neg'),
#  ([''], 'neg'),
#  (['นี้',
#    'ไง',
#    'ถึง',
#    'ไม่',
#    'อยาก',
#    'ให้',
#    'รู้',
#    'เพราะ',
#    'ว่า',
#    'วุ่นวาย',
#    'เเค่',
#    'นี้',
#    'กพอ',
#    'เเล้ว'],
#   'neg'),
#  ...]

# %%
def get_words_in_sentences(sentences):
    all_words = []
    for (words, sentiment) in sentences:
        all_words.extend(words)
    return all_words

# %%
def get_word_features(wordlist):
    wordlist = FreqDist(wordlist)
    word_features = [word[0] for word in wordlist.most_common()]
    return word_features

# %%
def extract_features(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in document_words)
    return features

# %%
features_data = np.array(sentences)
# แบ่งข้อมูลเป็น 10 ชุด โดยไม่เรียง
k_fold = KFold(n_splits=10, random_state=1992, shuffle=True)
word_features = None
accuracy_scores = []
for train_set, test_set in k_fold.split(features_data):
    word_features = get_word_features(get_words_in_sentences(features_data[train_set].tolist()))
    train_features = apply_features(extract_features, features_data[train_set].tolist())
    test_features = apply_features(extract_features, features_data[test_set].tolist())
    classifier = NaiveBayesClassifier.train(train_features)
    refsets = collections.defaultdict(set)
    testsets = collections.defaultdict(set)
    for i, (feats, label) in enumerate(test_features):
        refsets[label].add(i)
        observed = classifier.classify(feats)
        testsets[observed].add(i)
    accuracy_score = util.accuracy(classifier, test_features)
    print('train: {} test: {}'.format(len(train_set), len(test_set)))
    print('=================== Results ===================')
    print('Accuracy {:f}'.format(accuracy_score))
    print('            Positive     Negative')
    print('F1         [{:f}     {:f}]'.format(
        f_measure(refsets['pos'], testsets['pos']),
        f_measure(refsets['neg'], testsets['neg'])
    ))
    print('Precision  [{:f}     {:f}]'.format(
        precision(refsets['pos'], testsets['pos']),
        precision(refsets['neg'], testsets['neg'])
    ))
    print('Recall     [{:f}     {:f}]'.format(
        recall(refsets['pos'], testsets['pos']),
        recall(refsets['neg'], testsets['neg'])
    ))
    print('===============================================\n')
# Out:
# train: 1911 test: 213
# =================== Results ===================
# Accuracy 0.704225
#             Positive     Negative
# F1         [0.540146     0.782007]
# Precision  [0.804348     0.676647]
# Recall     [0.406593     0.926230]
# ===============================================
#
# train: 1911 test: 213
# =================== Results ===================
# Accuracy 0.690141
#             Positive     Negative
# F1         [0.500000     0.775510]
# Precision  [0.891892     0.647727]
# Recall     [0.347368     0.966102]
# ===============================================
#
# train: 1911 test: 213
# =================== Results ===================
# Accuracy 0.694836
#             Positive     Negative
# F1         [0.480000     0.784053]
# Precision  [0.833333     0.666667]
# Recall     [0.337079     0.951613]
# ===============================================
#
# train: 1911 test: 213
# =================== Results ===================
# Accuracy 0.652582
#             Positive     Negative
# F1         [0.439394     0.748299]
# Precision  [0.805556     0.621469]
# Recall     [0.302083     0.940171]
# ===============================================
#
# train: 1912 test: 212
# =================== Results ===================
# Accuracy 0.655660
#             Positive     Negative
# F1         [0.474820     0.743860]
# Precision  [0.891892     0.605714]
# Recall     [0.323529     0.963636]
# ===============================================
#
# train: 1912 test: 212
# =================== Results ===================
# Accuracy 0.712264
#             Positive     Negative
# F1         [0.504065     0.797342]
# Precision  [0.794872     0.693642]
# Recall     [0.369048     0.937500]
# ===============================================
#
# train: 1912 test: 212
# =================== Results ===================
# Accuracy 0.641509
#             Positive     Negative
# F1         [0.377049     0.748344]
# Precision  [0.766667     0.620879]
# Recall     [0.250000     0.941667]
# ===============================================
#
# train: 1912 test: 212
# =================== Results ===================
# Accuracy 0.650943
#             Positive     Negative
# F1         [0.393443     0.754967]
# Precision  [0.750000     0.633333]
# Recall     [0.266667     0.934426]
# ===============================================
#
# train: 1912 test: 212
# =================== Results ===================
# Accuracy 0.707547
#             Positive     Negative
# F1         [0.530303     0.787671]
# Precision  [0.897436     0.664740]
# Recall     [0.376344     0.966387]
# ===============================================
#
# train: 1912 test: 212
# =================== Results ===================
# Accuracy 0.655660
#             Positive     Negative
# F1         [0.467153     0.745645]
# Precision  [0.888889     0.607955]
# Recall     [0.316832     0.963964]
# ===============================================
